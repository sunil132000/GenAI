# %% [markdown]
# # Sets
#
# - Sets are going to be our third data structure which can store values inside it within the curly braces {} and are known for storing the values which are Non-Duplicate and unique

# %%
a = set()
type(a)
# Out:
# set

# %%
set_value ={1,2,4,5,6,3,2,5,78,8,5,3}
print(set_value)
# Out:
# {1, 2, 3, 4, 5, 6, 8, 78}

# %% [markdown]
# ### Set Method
#
# - add()---> it is going to used in sets for inserting our values inside a set from last

# %%
set_value.add(33)
print(set_value)
# Out:
# {1, 2, 3, 4, 5, 6, 66, 8, 33, 44, 78, 55}
