# %% [markdown]
# # Data Structure

# %% [markdown]
# ## Data Structure in Python are being used for storing the data in a structured format so that we can access the data and along with that we can perform all of the operations with these data structures that we can perform in the case of database as well like crud(create , read , update , delete) operations

# %% [markdown]
# Type of Data Structure are :
#   1. List
#   2. Tuple<br>
#  3.Set
#   4. Dictionary

# %% [markdown]
# The different types of data structures differs on this basis that in which specific format we want to store our data.
