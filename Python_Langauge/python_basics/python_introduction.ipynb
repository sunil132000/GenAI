# %% [markdown]
# # What is Python Language

# %% [markdown]
# ## Python is a Type of programming language which we can use for communicating with computers or technology

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# 1. Python is case Sensitive

# %%
name = "amit"
Name = "Amit"
name==Name
# Out:
# False

# %% [markdown]
# # Indentation in Python

# %% [markdown]
# ## In ohter programming langauge , we use {} for grouping of statements
# ## In python , we use Indentation for proper grouping of statements as the proper arrangement of
# ## statements with proper spacing in the statements within a block

# %%
age = int(input("enter you age: "))
if age > 18 :
    print("You are eligible for drving ")
# Out:
# You are eligible for drving

# %%
# line Continuation --> we can ue Backslash for continuing the statement on the next line
1+2+3+4\
    +6+7
# Out:
# 23

# %%
# semicolon is used to write multiple line code in a single line
a =5 ;  b=6
