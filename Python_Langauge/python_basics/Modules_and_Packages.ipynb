# %% [markdown]
# # Modules and Packages
#
# - A Modules in Python is simply a file containing python code (function , classes or variable ) that can be imported and used in other programs
#
# - NUMPY - Numpy Module is going to help us out applying scientific calculation on the array and we store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the List(We can Do it in Numpy just because Numpy is having the collection of function and attribute which can help us to work efficiently with the array) .
#
# - PANDAS - Pandas we can use when we are going to work with the dataset for cleaning , pre processing , EDA , analysis with plotting as well

# %% [markdown]
# - A Module - A module helps in code organization , It promotes reusability, It keeps the code clean and manageable

# %%
# all way we can import
import math
from math import sqrt
from math import *

# %% [markdown]
# - I am trying to create my own library or Module in this library i want the function and the attributes to be created on my own
# - __init--.py is a file that has to be their inside the package folder and this __init__.py file helps us out in defining our packages and initializing their namespaces
# - __init__.py file can remain empty and its completely fine but this file has to be their when we will be creating our new packages into the package folder
# - Earlier (Python < 3.3), without __init__.py, Python would not recognize the folder as a package.
# - Whatever you write inside __init__.py runs automatically when the package is imported.
