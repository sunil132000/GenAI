# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in python that can be used for storing data into it or values into it or they can be referred as containers as well .
# ## variables as per its name , data can vary that we are going to store into it and once we have declared a variable we can vary the value stored in it .

# %%
age = 23
Name = 'Sunil Kumar Singh'
Height  =5.5
is_true = True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.5

# %%
# python is case sensitive
height
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 height
#
# NameError: name 'height' is not defined

# %% [markdown]
# ## print() ---> print function is being used to represent the value that we are going to pass inside it

# %%
print(Name)
print("height is:" , Height)
# Out:
# Sunil Kumar Singh
# height is: 5.5

# %% [markdown]
# ## Interpreter --> executes the code line by line in python language

# %% [markdown]
# sinlge line comment --> #
# multy line comment --> '''   comment '''

# %% [markdown]
# # Varaible Naming COnvention

# %%
''' 1. Variable names must be Descriptive :
    Age = 23

    2. They must start with a letter or underscore and can contain letter , numbers and underscores
    ex - a. 1name ( Wrong)
         b. _name ( Correct)

    3. Variables are also case sensitive

    4.
'''
# Out:
# ' Varibale names must be Descriptive :\n'

# %% [markdown]
# ## Type() method give you type of variable it store

# %%
Name="Sunil Kumar Singh"
print(type(Name))
# Out:
# <class 'str'>

# %% [markdown]
# ## str() method is used to convert the data type of variable to string

# %%
age  =23
print(type(age))
print(type(str(age)))
# Out:
# <class 'int'>
# <class 'str'>

# %%
Name = "Amit"
''' Every Type casting is Not possible
  a.int ---> str possible ( by str() method)
  b.str ----> int not possible  '''
Name = int(Name) #Wrong
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       1 Name = "Amit"
#       2 ''' Every Type casting is Not possible
#       3   a.int ---> str possible ( by str() method)
#       4   b.str ----> int not possible  '''
# ----> 5 Name = int(Name) #Wrong
#
# ValueError: invalid literal for int() with base 10: 'Amit'

# %% [markdown]
# ## input() method is used to take input from the user side and then can store that input into a variable

# %% [markdown]
# ## Input function only takes the input in a string format until and unless we are not going to explicitly take the input in integer or other format

# %%
Name  = input("Enter you name")
print(Name)
# Out:
# sadf
#
#
# asf

# %%
Age = input("Enter your age" )
# even taking integer as input it store it as string
print(type(Age))
#so we need to explicitly type cast it
Age = int(input("Enter your age"))
print(type(Age))
''' a. for float use float()
    b. for boolean use bool() '''
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Building a Simple Calculator

value_1 = int(input("Enter a first number"))
value_2 = int(input("Enter a second number"))
print("the addition for the values is ", value_1+value_2)
print("the addition for the values is ", value_1-value_2)
# Out:
# the addition for the values is  32
# the addition for the values is  -2
