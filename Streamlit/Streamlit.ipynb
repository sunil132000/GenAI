# %% [markdown]
# # Streamlit
#
# - Streamlit is an Open source Library used to build Beautiful , interactive web applications for data science and machine learning with minimal effort
#
#
# ### Why to use Streamlit
#  - Easy to use
#  - Fast Development
#   - Interactive UI Elements  --> BUttons , Sliders , Text inputs , charts , etc
#   - Great for data science --> Supports Pandas , Matlplotlib , Plotly and other libraries
#   - Development easy

# %% [markdown]
# #### Methods  - method are case sensitive
# - write()
# - title()
# - header()
# - subheader()
# - text()
# - button()
# - checkbox()
# - slider()
# - file_uploader("upload a file , type=["csv,"txt])
# -

# %%
import streamlit as st
st.write("Hello World")
# Out:
# 2026-05-05 11:53:07.837 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 11:53:08.763
# ...
#   command:
#
#     streamlit run C:\Users\Sunil.Singh02\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-05 11:53:08.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-05 11:53:08.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
